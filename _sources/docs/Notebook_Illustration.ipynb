# %% [markdown]
# # This is a markdown cell in edit mode
#
# $f(x) = \sin(x)$

# %% [markdown]
# # This is a markdown cell in normal view
#
# $f(x) = \sin(x)$

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 2 * np.pi, 0.01)
f = np.sin(x)

plt.plot(x,f)
plt.grid('on')
plt.show()
