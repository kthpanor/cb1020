# %% [markdown]
# (sec:nn)=
# # Neural networks

# %% [markdown]
# ## Additional material

# %% [markdown]
# Watch the series of four videos on neural networks from the (generally) excellent channel [3Blue1Brown](https://www.youtube.com/@3blue1brown).

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("aircAruvnKk?si=p7eKKqYI8u8mqfIb")
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/aircAruvnKk?si=p7eKKqYI8u8mqfIb"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
